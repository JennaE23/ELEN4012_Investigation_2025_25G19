# %%
import qiskit
from qiskit import QuantumCircuit #Aer, IBMQ,
from qiskit.visualization import plot_histogram
from qiskit import transpile
from qiskit.providers import fake_provider
#from qiskit.providers.fake_provider import GenericBackendV2
from qiskit.providers.basic_provider import BasicSimulator
from qiskit_ibm_runtime import QiskitRuntimeService
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_ibm_runtime import SamplerV2 as Sampler

# importing datetime module for now()
import datetime
import matplotlib

# %%
import circuit_funcs
import data_extract_funcs

# %%
fake_backends =['']

# %%
nr_qubits= 4
sim_backend = fake_provider.FakeBackend('fake_torino')
#backend =service.backend(backend_name)
qc_set = circuit_funcs.make_set_of_3(nr_qubits)

# Transpile the ideal circuit to a circuit that can be directly executed by the backend
transpiled_circuits = transpile(qc_set, sim_backend)

# Run the transpiled circuit using the simulated backend
job = sim_backend.run(transpiled_circuits,shots =4096,memory=False)
result = job.result()
#result1 = result.result()
print(result.get_counts()[0])
# Out:
# C:\Users\epste\AppData\Local\Temp\ipykernel_19100\1939091134.py:2: DeprecationWarning: The class ``qiskit.providers.fake_provider.fake_backend.FakeBackend`` is deprecated as of qiskit 1.2. It will be removed in the 2.0 release. Fake backends using BackendV1 are deprecated in favor of :class:`.GenericBackendV2`. You can convert BackendV1 to :class:`.BackendV2` with :class:`.BackendV2Converter`.
#   sim_backend = fake_provider.FakeBackend('fake_torino')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 7
#       4 qc_set = circuit_funcs.make_set_of_3(nr_qubits)
#       6 # Transpile the ideal circuit to a circuit that can be directly executed by the backend
# ----> 7 transpiled_circuits = transpile(qc_set, sim_backend)
#       9 # Run the transpiled circuit using the simulated backend
#      10 job = sim_backend.run(transpiled_circuits,shots =4096,memory=False)
#
# File c:\Users\epste\anaconda3\envs\qiskE\Lib\site-packages\qiskit\utils\deprecation.py:184, in deprecate_arg.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     171 @functools.wraps(func)
#     172 def wrapper(*args, **kwargs):
#     173     _maybe_warn_and_rename_kwarg(
#     174         args,
#     175         kwargs,
#    (...)
#     182         predicate=predicate,
#     183     )
# --> 184     return func(*args, **kwargs)
#
# File c:\Users\epste\anaconda3\envs\qiskE\Lib\site-packages\qiskit\utils\deprecation.py:184, in deprecate_arg.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     171 @functools.wraps(func)
#     172 def wrapper(*args, **kwargs):
#     173     _maybe_warn_and_rename_kwarg(
#     174         args,
#     175         kwargs,
#    (...)
#     182         predicate=predicate,
#     183     )
# --> 184     return func(*args, **kwargs)
#
#     [... skipping similar frames: deprecate_arg.<locals>.decorator.<locals>.wrapper at line 184 (1 times)]
#
# File c:\Users\epste\anaconda3\envs\qiskE\Lib\site-packages\qiskit\utils\deprecation.py:184, in deprecate_arg.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     171 @functools.wraps(func)
#     172 def wrapper(*args, **kwargs):
#     173     _maybe_warn_and_rename_kwarg(
#     174         args,
#     175         kwargs,
#    (...)
#     182         predicate=predicate,
#     183     )
# --> 184     return func(*args, **kwargs)
#
# File c:\Users\epste\anaconda3\envs\qiskE\Lib\site-packages\qiskit\compiler\transpiler.py:351, in transpile(circuits, backend, basis_gates, inst_map, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, scheduling_method, instruction_durations, dt, approximation_degree, timing_constraints, seed_transpiler, optimization_level, callback, output_name, unitary_synthesis_method, unitary_synthesis_plugin_config, target, hls_config, init_method, optimization_method, ignore_backend_supplied_default_methods, num_processes, qubits_initially_zero)
#     346     optimization_level = config.get("transpile_optimization_level", 2)
#     348 if backend is not None and getattr(backend, "version", 0) <= 1:
#     349     warnings.warn(
#     350         "The `transpile` function will stop supporting inputs of "
# --> 351         f"type `BackendV1` ( {backend} ) in the `backend` parameter in a future "
#     352         "release no earlier than 2.0. `BackendV1` is deprecated and implementations "
#     353         "should move to `BackendV2`.",
#     354         category=DeprecationWarning,
#     355         stacklevel=2,
#     356     )
#     357     with warnings.catch_warnings():
#     358         # This is a temporary conversion step to allow for a smoother transition
#     359         # to a fully target-based transpiler pipeline while maintaining the behavior
#    (...)
#     362         #   removed once it gets removed:
#     363         #   https://github.com/Qiskit/qiskit/pull/12850
#     364         warnings.filterwarnings(
#     365             "ignore",
#     366             category=DeprecationWarning,
#     367             message=r".+qiskit\.providers\.backend_compat\.BackendV2Converter.+",
#     368             module="qiskit",
#     369         )
#
# File c:\Users\epste\anaconda3\envs\qiskE\Lib\site-packages\qiskit\providers\backend.py:193, in BackendV1.__str__(self)
#     192 def __str__(self):
# --> 193     return self.name()
#
# File c:\Users\epste\anaconda3\envs\qiskE\Lib\site-packages\qiskit\providers\backend.py:190, in BackendV1.name(self)
#     184 def name(self):
#     185     """Return the backend name.
#     186
#     187     Returns:
#     188         str: the name of the backend.
#     189     """
# --> 190     return self._configuration.backend_name
#
# AttributeError: 'str' object has no attribute 'backend_name'
