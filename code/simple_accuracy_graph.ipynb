# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

from investigation_functions import ml_visualisation_funcs as mvf

# %%
df_svm_4q = pd.read_csv('../ML_results/SVM/svm_4q.csv')
df_svm_8q = pd.read_csv('../ML_results/SVM/svm_8q.csv')
df_svm_16q_c111 = pd.read_csv('../ML_results/SVM/svm_16q_HSR_c111.csv')

# %%
df_knn_4q = pd.read_csv('../ML_results/KNN/knn_4q.csv')
df_knn_8q = pd.read_csv('../ML_results/KNN/knn_8q.csv')
df_knn_16q_c111 = pd.read_csv('../ML_results/KNN/knn_16q_HSR_c111.csv')

# %%
df_svm_4q = df_svm_4q[df_svm_4q['machines'] == 1111]
df_svm_8q = df_svm_8q[df_svm_8q['machines'] == 1111]

# %%
df_knn_4q = df_knn_4q[df_knn_4q['machines'] == 1111]
df_knn_8q = df_knn_8q[df_knn_8q['machines'] == 1111]

# %%
df_svm_4q_hsr_c111 = df_svm_4q[df_svm_4q['tr&v circuits'] == 111]
df_svm_8q_hsr_c111 = df_svm_8q[df_svm_8q['tr&v circuits'] == 111]

# %%
df_knn_4q_hsr_c111 = df_knn_4q[df_knn_4q['tr&v circuits'] == 111]
df_knn_8q_hsr_c111 = df_knn_8q[df_knn_8q['tr&v circuits'] == 111]

# %%
df_knn_4q_hsr_c111.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60 entries, 0 to 59
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   nr_qubits            60 non-null     int64
#  1   machines             60 non-null     int64
#  2   tr&v exp_type        60 non-null     object
#  3   tr&v circuits        60 non-null     int64
#  4   test exp_type        60 non-null     object
#  5   test circuits        60 non-null     int64
#  6   preprocess settings  60 non-null     int64
#  7   n_neighbors          60 non-null     object
#  8   param settings       60 non-null     int64
#  9   accuracy             60 non-null     float64
#  10  cv_1                 20 non-null     float64
#  11  cv_2                 20 non-null     float64
#  12  cv_3                 20 non-null     float64
#  13  cv_4                 20 non-null     float64
#  14  cv_5                 20 non-null     float64
# ...

# %%
df_4q = pd.concat([df_svm_4q_hsr_c111.drop('kernal', axis=1),df_knn_4q_hsr_c111.drop('n_neighbors', axis=1)],ignore_index=True)

# %%
df_4q.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   nr_qubits            120 non-null    int64
#  1   machines             120 non-null    int64
#  2   tr&v exp_type        120 non-null    object
#  3   tr&v circuits        120 non-null    int64
#  4   test exp_type        120 non-null    object
#  5   test circuits        120 non-null    int64
#  6   preprocess settings  120 non-null    int64
#  7   param settings       120 non-null    int64
#  8   accuracy             120 non-null    float64
#  9   cv_1                 40 non-null     float64
#  10  cv_2                 40 non-null     float64
#  11  cv_3                 40 non-null     float64
#  12  cv_4                 40 non-null     float64
#  13  cv_5                 40 non-null     float64
# dtypes: float64(6), int64(6), object(2)
# memory usage: 13.3+ KB

# %%
df_8q = pd.concat([df_svm_8q_hsr_c111.drop('kernal', axis = 1),df_knn_8q_hsr_c111.drop('n_neighbors',axis =1)],ignore_index=True)
# df_16q = pd.concat([df_svm_16q_c111,df_knn_16q_c111],ignore_index=True)
df_8q.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   nr_qubits            120 non-null    int64
#  1   machines             120 non-null    int64
#  2   tr&v exp_type        120 non-null    object
#  3   tr&v circuits        120 non-null    int64
#  4   test exp_type        120 non-null    object
#  5   test circuits        120 non-null    int64
#  6   preprocess settings  120 non-null    int64
#  7   param settings       120 non-null    int64
#  8   accuracy             120 non-null    float64
#  9   cv_1                 40 non-null     float64
#  10  cv_2                 40 non-null     float64
#  11  cv_3                 40 non-null     float64
#  12  cv_4                 40 non-null     float64
#  13  cv_5                 40 non-null     float64
# dtypes: float64(6), int64(6), object(2)
# memory usage: 13.3+ KB

# %%
df_16q = pd.concat([df_svm_16q_c111.drop('kernal', axis=1),df_knn_16q_c111.drop('n_neighbors', axis=1)],ignore_index=True)
df_16q.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   nr_qubits            120 non-null    int64
#  1   machines             120 non-null    int64
#  2   tr&v exp_type        120 non-null    object
#  3   tr&v circuits        120 non-null    int64
#  4   test exp_type        120 non-null    object
#  5   test circuits        120 non-null    int64
#  6   preprocess settings  120 non-null    int64
#  7   param settings       120 non-null    int64
#  8   accuracy             120 non-null    float64
#  9   cv_1                 40 non-null     float64
#  10  cv_2                 40 non-null     float64
#  11  cv_3                 40 non-null     float64
#  12  cv_4                 40 non-null     float64
#  13  cv_5                 40 non-null     float64
# dtypes: float64(6), int64(6), object(2)
# memory usage: 13.3+ KB

# %%
df_16q.head()
# Out:
#    nr_qubits  machines tr&v exp_type  tr&v circuits         test exp_type  \
# 0         16      1111      Hardware            111              Hardware
# 1         16      1111      Hardware            111            Simulation
# 2         16      1111      Hardware            111  Refreshed_Simulation
# 3         16      1111      Hardware            111     Sim and Refreshed
# 4         16      1111    Simulation            111            Simulation
#
#    test circuits  preprocess settings  param settings  accuracy      cv_1  \
# 0            111                    0               0  0.716667  0.708333
# 1            111                    0               0  0.232737       NaN
# 2            111                    0               0  0.250000       NaN
# 3            111                    0               0  0.241466       NaN
# 4            111                    0               0  1.000000  0.968085
#
#        cv_2      cv_3      cv_4     cv_5
# ...

# %%
df_4q = df_4q[df_4q['tr&v exp_type'] == df_4q['test exp_type']]
df_4q.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40 entries, 0 to 118
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   nr_qubits            40 non-null     int64
#  1   machines             40 non-null     int64
#  2   tr&v exp_type        40 non-null     object
#  3   tr&v circuits        40 non-null     int64
#  4   test exp_type        40 non-null     object
#  5   test circuits        40 non-null     int64
#  6   preprocess settings  40 non-null     int64
#  7   param settings       40 non-null     int64
#  8   accuracy             40 non-null     float64
#  9   cv_1                 40 non-null     float64
#  10  cv_2                 40 non-null     float64
#  11  cv_3                 40 non-null     float64
#  12  cv_4                 40 non-null     float64
#  13  cv_5                 40 non-null     float64
# dtypes: float64(6), int64(6), object(2)
# memory usage: 4.7+ KB

# %%
df_4q.head()
# Out:
#     nr_qubits  machines         tr&v exp_type  tr&v circuits  \
# 0           4      1111              Hardware            111
# 4           4      1111            Simulation            111
# 7           4      1111  Refreshed_Simulation            111
# 10          4      1111     Sim and Refreshed            111
# 12          4      1111              Hardware            111
#
#            test exp_type  test circuits  preprocess settings  param settings  \
# 0               Hardware            111                    0               0
# 4             Simulation            111                    0               0
# 7   Refreshed_Simulation            111                    0               0
# 10     Sim and Refreshed            111                    0               0
# 12              Hardware            111                    0               1
#
#     accuracy      cv_1      cv_2      cv_3      cv_4      cv_5
# 0   0.992248  1.000000  0.980583  1.000000  0.990196  1.000000
# ...

# %%
df_8q = df_8q[df_8q['tr&v exp_type'] == df_8q['test exp_type']]
df_16q = df_16q[df_16q['tr&v exp_type'] == df_16q['test exp_type']]

# %%
df_8q.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40 entries, 0 to 118
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   nr_qubits            40 non-null     int64
#  1   machines             40 non-null     int64
#  2   tr&v exp_type        40 non-null     object
#  3   tr&v circuits        40 non-null     int64
#  4   test exp_type        40 non-null     object
#  5   test circuits        40 non-null     int64
#  6   preprocess settings  40 non-null     int64
#  7   param settings       40 non-null     int64
#  8   accuracy             40 non-null     float64
#  9   cv_1                 40 non-null     float64
#  10  cv_2                 40 non-null     float64
#  11  cv_3                 40 non-null     float64
#  12  cv_4                 40 non-null     float64
#  13  cv_5                 40 non-null     float64
# dtypes: float64(6), int64(6), object(2)
# memory usage: 4.7+ KB

# %%
df_full = pd.concat([df_4q,df_8q,df_16q],ignore_index=True)
df_full['accuracy'] = df_full['accuracy']*100

# %%
plt.figure(figsize=(10,6))
sns.barplot(
    data = df_full,
    x = 'nr_qubits',
    y = 'accuracy',
    hue= 'tr&v exp_type'    
)
plt.ylim(tuple([50,100]))
plt.title('ML Model Accuracy vs Size of Algorithm')
plt.xlabel('Size of Algorithm (Number of Qubits)')
plt.ylabel('Accuracy (%)')
plt.legend(title='Experiment Type',loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
# df_HS = df_full[df_full['tr&v exp_type'] == 'Hardware' | df_full['tr&v exp_type'] == 'Simulation']
df_HS = pd.concat([df_full[df_full['tr&v exp_type'] == 'Hardware'],df_full[df_full['tr&v exp_type'] == 'Simulation']],ignore_index=True)

# %%
import matplotlib.colors as mcolors
plt.figure(figsize=(10,6))
sns.barplot(
    data = df_HS,
    x = 'nr_qubits',
    y = 'accuracy',
    hue= 'tr&v exp_type' ,
    palette=[mcolors.CSS4_COLORS['blue'],mcolors.CSS4_COLORS['darkturquoise']],
    errorbar = None
)
plt.grid(linestyle = 'dotted')
plt.ylim(tuple([50,100]))
plt.title('ML Model Accuracy vs Size of Algorithm',fontsize = 17, y = 1.05)
plt.xlabel('Size of Algorithm (Number of Qubits)',fontsize = 15)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.ylabel('Accuracy (%)',fontsize = 15)
plt.legend(title='Experiment Type',loc='center left', bbox_to_anchor=(1, 0.5),fontsize = 15, title_fontsize = 15)
plt.show()
