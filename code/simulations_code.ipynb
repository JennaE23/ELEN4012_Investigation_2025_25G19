# %%
import qiskit
from qiskit import QuantumCircuit #Aer, IBMQ,
from qiskit.visualization import plot_histogram
from qiskit import transpile
#from qiskit.providers import fake_provider
from qiskit.providers.fake_provider import GenericBackendV2
from qiskit_ibm_runtime import SamplerV2 as Sampler
from qiskit_ibm_runtime.fake_provider import FakeManilaV2, FakeTorino, FakeBrisbane
from qiskit_ibm_runtime.fake_provider import FakeFez, FakeMarrakesh
#fez, marrakesh are both Heron2
from qiskit.providers.basic_provider import BasicSimulator
from qiskit_ibm_runtime import QiskitRuntimeService
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager


# importing datetime module for now()
import datetime
import matplotlib

# %%
import circuit_funcs
import data_extract_funcs
import sim_function

# %%
def make_file_names(backend_name,is_sim,nr_qubits):
    base_name = nr_qubits +"q_"
    if is_sim:
        base_name = base_name +"fake_"
    base_name = base_name +backend_name

    file_names = []
    for i in range(1,4):
        temp_name = base_name + str(i) +".csv"
        file_names.append(temp_name)
    return file_names

def run_sims_for_all_backends(fake_backends, nr_qubits,nr_runs,dir_,create_csvs_):
    for fake_backend in fake_backends:
        file_names = make_file_names(fake_backend.backend_name,False,str(nr_qubits))
        sim_function.get_and_save_sim_results(nr_qubits,fake_backend,1,file_names,create_csvs_,dir_)
        for i in range(nr_runs-1):
            sim_function.get_and_save_sim_results(nr_qubits,fake_backend,1,file_names,False,dir_)

# %% [markdown]
# To complete 1 run with 16 qubits: FakeFez takes 16s, FakeBrisbane takes 1 min 36s, FakeTorino takes 8.8s, FakeMarrakesh takes 11.4s.

# %%
# nr_qubits =16
# nr_runs = 5

# fake_backend = FakeTorino()

# # service = QiskitRuntimeService()
# #fake_backend.refresh(service)

# is_sim = True
# file_names = make_file_names("torino",is_sim,str(nr_qubits))
# dir_ = "../Simulated_results/16q/"

# #True if new files must be created, False if you wish to append
# create_csvs_ =False


# sim_function.get_and_save_sim_results(nr_qubits,fake_backend,nr_runs,file_names,create_csvs_,dir_)

# %%
fake_backends = [FakeTorino(),FakeFez(),FakeMarrakesh(),FakeBrisbane()]

# %% [markdown]
# Run the block below: dont forget to change the directory

# %%
dir_ = "../Simulated_results/4q/"
create_csvs_ = False # if true, it creates and overwrites, if flase, it just appends
runs= 50
nr_qubits = 4

run_sims_for_all_backends(fake_backends,nr_qubits,runs,dir_,create_csvs_)
# Out:
# ---------------------------------------------------------------------------
# QiskitError                               Traceback (most recent call last)
# Cell In[14], line 3
#       1 dir_ = "../Simulated_results/32q/"
#       2 create_csvs_ = True
# ----> 3 run_sims_for_all_backends(fake_backends,32,50,dir_,create_csvs_)
#
# Cell In[13], line 4, in run_sims_for_all_backends(fake_backends, nr_qubits, nr_runs, dir_, create_csvs_)
#       2 for fake_backend in fake_backends:
#       3     file_names = make_file_names(fake_backend.backend_name,False,str(nr_qubits))
# ----> 4     sim_function.get_and_save_sim_results(nr_qubits,fake_backend,1,file_names,create_csvs_,dir_)
#       5     for i in range(nr_runs-1):
#       6         sim_function.get_and_save_sim_results(nr_qubits,fake_backend,1,file_names,False,dir_)
#
# File c:\Users\epste\OneDrive\Documents\Uni\2025 4th Year\sem 2\Investigation\Code\ELEN4012_Investigation_2025_25G19\code\sim_function.py:6, in get_and_save_sim_results(nr_qubits, fake_backend, nr_runs, output_file_names, create_csvs_, dir_)
#       4 def get_and_save_sim_results(nr_qubits,fake_backend,nr_runs,output_file_names,create_csvs_,dir_):
#       5     qc_set = circuit_funcs.make_set_of_3(nr_qubits)
# ----> 6     results_list = circuit_funcs.run_sim(fake_backend,qc_set,nr_runs)
#       7     data_extract_funcs.sim_results_to_csv(nr_qubits,output_file_names,results_list,create_csvs_,dir_)
#
# File c:\Users\epste\OneDrive\Documents\Uni\2025 4th Year\sem 2\Investigation\Code\ELEN4012_Investigation_2025_25G19\code\circuit_funcs.py:89, in run_sim(fake_backend, qc_set, nr_runs)
#      87 for run in range(nr_runs):
#      88     job = sim_backend.run(transpiled_circuits,shots =4096,memory=False)
# ---> 89     results.append(job.result().get_counts())
#      91 return results
#
# File c:\Users\epste\anaconda3\envs\qiskE\Lib\site-packages\qiskit\result\result.py:256, in Result.get_counts(self, experiment)
#     254 dict_list = []
#     255 for key in exp_keys:
# --> 256     exp = self._get_experiment(key)
#     257     try:
#     258         header = exp.header
#
# File c:\Users\epste\anaconda3\envs\qiskE\Lib\site-packages\qiskit\result\result.py:385, in Result._get_experiment(self, key)
#     383 result_status = getattr(self, "status", "Result was not successful")
#     384 exp_status = getattr(exp, "status", "Experiment was not successful")
# --> 385 raise QiskitError(result_status, ", ", exp_status)
#
# QiskitError: 'ERROR:  [Experiment 0] a circuit requires more memory than max_memory_mb. [Experiment 1] a circuit requires more memory than max_memory_mb. [Experiment 2] a circuit requires more memory than max_memory_mb. ,  ERROR: a circuit requires more memory than max_memory_mb.'

# %%
nr_qubits =4
nr_runs =1
fake_backend = GenericBackendV2(nr_qubits)
dir_ = "../Simulated_results/4q/"

is_sim = True
file_names = make_file_names("genericV2",is_sim,str(nr_qubits))

#True if new files must be created, False if you wish to append
create_csvs_ =False


for i in range(nr_runs):
    sim_function.get_and_save_sim_results(nr_qubits,fake_backend,1,file_names,create_csvs_,dir_)
# Out:
# ---------------------------------------------------------------------------
# QiskitError                               Traceback (most recent call last)
# Cell In[15], line 13
#      11 nr_runs =1
#      12 for i in range(nr_runs):
# ---> 13     sim_function.get_and_save_sim_results(nr_qubits,fake_backend,1,file_names,create_csvs_,dir_)
#
# File c:\Users\epste\OneDrive\Documents\Uni\2025 4th Year\sem 2\Investigation\Code\ELEN4012_Investigation_2025_25G19\code\sim_function.py:6, in get_and_save_sim_results(nr_qubits, fake_backend, nr_runs, output_file_names, create_csvs_, dir_)
#       4 def get_and_save_sim_results(nr_qubits,fake_backend,nr_runs,output_file_names,create_csvs_,dir_):
#       5     qc_set = circuit_funcs.make_set_of_3(nr_qubits)
# ----> 6     results_list = circuit_funcs.run_sim(fake_backend,qc_set,nr_runs)
#       7     data_extract_funcs.sim_results_to_csv(nr_qubits,output_file_names,results_list,create_csvs_,dir_)
#
# File c:\Users\epste\OneDrive\Documents\Uni\2025 4th Year\sem 2\Investigation\Code\ELEN4012_Investigation_2025_25G19\code\circuit_funcs.py:89, in run_sim(fake_backend, qc_set, nr_runs)
#      87 for run in range(nr_runs):
#      88     job = sim_backend.run(transpiled_circuits,shots =4096,memory=False)
# ---> 89     results.append(job.result().get_counts())
#      91 return results
#
# File c:\Users\epste\anaconda3\envs\qiskE\Lib\site-packages\qiskit\result\result.py:256, in Result.get_counts(self, experiment)
#     254 dict_list = []
#     255 for key in exp_keys:
# --> 256     exp = self._get_experiment(key)
#     257     try:
#     258         header = exp.header
#
# File c:\Users\epste\anaconda3\envs\qiskE\Lib\site-packages\qiskit\result\result.py:385, in Result._get_experiment(self, key)
#     383 result_status = getattr(self, "status", "Result was not successful")
#     384 exp_status = getattr(exp, "status", "Experiment was not successful")
# --> 385 raise QiskitError(result_status, ", ", exp_status)
#
# QiskitError: 'ERROR:  [Experiment 0] a circuit requires more memory than max_memory_mb. [Experiment 1] a circuit requires more memory than max_memory_mb. [Experiment 2] a circuit requires more memory than max_memory_mb. ,  ERROR: a circuit requires more memory than max_memory_mb.'
