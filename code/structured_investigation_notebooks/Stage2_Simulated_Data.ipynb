# %% [markdown]
# # Stage 2
#
# This notebook goes through the generation of our simulated data and the refreshed simulated data.

# %% [markdown]
# ### Imports

# %%
import sys
sys.path.append('../')
#import investigation_functions
from investigation_functions import  sim_function, data_extract_funcs
import config
import backend_vars

from qiskit.providers.fake_provider import GenericBackendV2
from qiskit_ibm_runtime.fake_provider import  FakeTorino, FakeBrisbane
from qiskit_ibm_runtime.fake_provider import FakeFez, FakeMarrakesh
from qiskit_ibm_runtime import QiskitRuntimeService

# %%
fake_backends = [FakeBrisbane(),FakeFez(),FakeMarrakesh(),FakeTorino()]
