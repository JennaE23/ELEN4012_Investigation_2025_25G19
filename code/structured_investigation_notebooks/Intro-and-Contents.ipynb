# %% [markdown]
# # Introduction
#
# This folder, 'structured_investigation_notebooks', contains notebooks that describe how we used the functions in 'investigation_functions' to arrive at our results.
#
# It is important to understand that this investigation was carried out through a few stages. Each stage is summarised in a notebook in this folder. Some notebooks may be shorter or longer depending on the complexity of our code for that stage.
#
# The following are the stages and their notebooks.
#
# ## Contents
# Part 1: Gathering Data
# 1. Stage 1: [Gathering Hardware data](Stage1_Hardware_Data.ipynb)
# 2. Stage 2: [Gathering Simulated Data](Stage2_Simulated_Data.ipynb)
# 3. Stage 3: [Labeling Data](Stage3_Labeling_Data.ipynb)
#
# Part 2: Generating Machine Learning Results
#
# 4. Stage 4: [Preprocessing Data](Stage4_Preprocessing_Data.ipynb)
# 5. Stage 5: [Creating Test Permutations](Stage5_Test_Permutations.ipynb)
# 6. Stage 6: [Machine Learning Pipeline](Stage6_ML_Pipeline.ipynb)
#
# Part 3: Interpreting Results
#
# 7. Stage 7: [Plotting results]()
