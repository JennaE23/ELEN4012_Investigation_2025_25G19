# %% [markdown]
# # Stage 8
#
# This notebook summarises the analysis of the noise fingerprints. The conclusions from the noise fingerprints are similar to the ML results conclusions.

# %% [markdown]
# ## Fingerprint plotting
#
# File: [Fingerprint_plotting](Further_detail/Fingerprint_plotting.ipynb)
#
# eg.
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Fingerprint Analysis
#
# File: [Fingerprint_metrics](Further_detail/Fingerprints_metrics.ipynb)
#
# This is where the various metrics are preliminarily tested,
# calculated and saved, and then plotted
