# %% [markdown]
# # Stage 6

# %% [markdown]
# This brief stage includes the code that is run in order to produce all of the Machine Learning results.

# %% [markdown]
# ## Imports

# %%
import sys
sys.path.append('../')

from investigation_functions import  ml_to_csv_funcs as ml2csv
from investigation_functions import  ml_funcs as mlf
from investigation_functions import  test_table_funcs as ttf
import backend_vars
from ml_models_vars import Param_Modes

from itertools import combinations

# %% [markdown]
# ## 1. All Permutations to csv

# %% [markdown]
# ## 2. Test-tables to csv

# %%
# nr_qubits =4
# initial_list = ttf.get_HSR_array_all_backends(nr_qubits) #[df_h,df_s, df_r]
# test_table_HSR4q = ttf.get_HSR_test_table(initial_list)
# ################################################

# %% [markdown]
# ## 3. All Permutations to csv

# %%
qubits_list = backend_vars.qubits_list
svm_modes = Param_Modes().SVM_modes
knn_modes_all_k = Param_Modes(knn_ks_=[7]).KNN_modes
# knn_modes_all_k = Param_Modes().KNN_modes
knn_5_modes = []
for knn_modes in knn_modes_all_k:
    knn_5_modes.append(knn_modes[0])

#To be changed if changing betw SVM and KNN:
dir_runs = "../../"
dir_ml = "../../ML_results/KNN/"
file_name = "knn_8q_v3.csv"
ml2csv.create_ml_results_csv('KNN',dir_ml,file_name)
param_modes = knn_5_modes
# param_modes = svm_modes
# param_modes_best_H_S_R=param_modes[2:5]#for backends
param_modes_best_H_S_R=[param_modes[4]] * 3

backend_list = ['brisbane','torino','fez','marrakesh']
# backend_list = ['brisbane','torino']#,'fez','marrakesh']
backend_list = ['brisbane','torino','fez','marrakesh']
backend_combos = list(combinations(backend_list, 2))



for qubit_nr in [8]:#qubits_list:
    initial_list = ttf.get_HSR_array_all_backends(
        qubit_nr,dir_runs, True,
        # incl_refr_H=True
    )
    
    ml2csv.run_and_record_HSR_c111(
        initial_list,dir_ml,file_name,param_modes)
    ml2csv.run_and_record_HSR_for_each_c_type(
        initial_list, dir_ml, file_name, param_modes)
    ml2csv.run_and_record_HSR_train_pairs(
        initial_list,dir_ml,file_name,param_modes
    )
    ml2csv.run_and_record_circuit_test_table(
      initial_list, dir_ml, file_name, param_modes)
    ml2csv.run_and_record_backends_v_backends(
        initial_list, dir_ml, file_name,param_modes_best_H_S_R, backend_combos
    )
    # ml2csv.run_and_record_bvb_for_each_c_type(
    #     initial_list, dir_ml, file_name,param_modes_best_H_S_R, backend_combos
    # )

# %% [markdown]
# ## Next stage -> [Stage 7 ](Stage7_ML_Results_Interpretation.ipynb)
