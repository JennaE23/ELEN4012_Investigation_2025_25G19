# %% [markdown]
# # SVM parameter testing
#
# Contents:
# 1. [4 Qubits](#4-qubits)
# 2. [8 Qubits](#8-qubits)
# 3. [16 Qubits](#16-qubits)

# %%
import sys
sys.path.append('../../')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from investigation_functions import data_process_funcs as dpf
from investigation_functions import ml_funcs as mlf
from investigation_functions import test_table_funcs as ttf

# %%
from sklearn.svm import SVC

# %%
model1 = SVC(kernel = 'poly',degree = 5)
model2 = SVC(kernel = 'rbf', C = 450)
model3 = SVC(kernel = 'poly', C = 450, coef0 = 0.5)
model4 = SVC(kernel = 'poly', C = 450, degree = 5)
model5 = SVC(kernel = 'linear', C = 450)

models = [model1, model2, model3, model4, model5]
model_names = ['poly_deg5', 'rbf_c450', 'poly_c450_coef0_0.5', 'poly_c450_deg5', 'linear_c450']

# %% [markdown]
# ## 4 Qubits

# %%
nr_qubits =4

initial_list = ttf.get_HSR_array_all_backends(
    nr_qubits,dir_='../../../', updated_results=True) #[df_h,df_s, df_r]

# %% [markdown]
# ### Hardware

# %%
S_scores = []

for model in models:
    fitted_model,score,cv_score = mlf.std_split_fit_and_scores(
        mlf.apply_preprosessing(initial_list[0]),model)
    print(f"Model={model}, Accuracy={score}, CV_Accuracy={cv_score.mean()}")
    print(f"CV_Scores={cv_score}")
    S_scores.append(cv_score.mean())

plt.plot(model_names, S_scores)
plt.xlabel('SVM Model')
plt.ylabel('Cross-Validated Accuracy')
plt.show()
# Out:
# Model=SVC(degree=5, kernel='poly'), Accuracy=0.9922480620155039, CV_Accuracy=0.9902722253950124
# CV_Scores=[0.99029126 0.98058252 0.99029126 0.99019608 1.        ]
# Model=SVC(C=450), Accuracy=1.0, CV_Accuracy=1.0
# CV_Scores=[1. 1. 1. 1. 1.]
# Model=SVC(C=450, coef0=0.5, kernel='poly'), Accuracy=1.0, CV_Accuracy=1.0
# CV_Scores=[1. 1. 1. 1. 1.]
# Model=SVC(C=450, degree=5, kernel='poly'), Accuracy=1.0, CV_Accuracy=1.0
# CV_Scores=[1. 1. 1. 1. 1.]
# Model=SVC(C=450, kernel='linear'), Accuracy=1.0, CV_Accuracy=1.0
# CV_Scores=[1. 1. 1. 1. 1.]

# %% [markdown]
# ### Old Simulation

# %%
df_S4 = initial_list[2]
df_S4p = mlf.apply_preprosessing(df_S4)

# %%
S_scores = []

for model in models:
    fitted_model,score,cv_score = mlf.std_split_fit_and_scores(df_S4p,model)
    print(f"Model={model}, Accuracy={score}, CV_Accuracy={cv_score.mean()}")
    print(f"CV_Scores={cv_score}")
    S_scores.append(cv_score.mean())

plt.plot(model_names, S_scores)
plt.xlabel('SVM Model')
plt.ylabel('Cross-Validated Accuracy')
plt.show()
# Out:
# Model=SVC(degree=5, kernel='poly'), Accuracy=0.5625, CV_Accuracy=0.5479166666666667
# CV_Scores=[0.55729167 0.609375   0.55208333 0.44270833 0.578125  ]
# Model=SVC(C=450), Accuracy=1.0, CV_Accuracy=0.99375
# CV_Scores=[0.98958333 1.         0.98958333 0.98958333 1.        ]
# Model=SVC(C=450, coef0=0.5, kernel='poly'), Accuracy=0.9958333333333333, CV_Accuracy=0.9947916666666667
# CV_Scores=[0.98958333 1.         0.99479167 0.98958333 1.        ]
# Model=SVC(C=450, degree=5, kernel='poly'), Accuracy=1.0, CV_Accuracy=0.9947916666666667
# CV_Scores=[0.98958333 1.         0.984375   1.         1.        ]
# Model=SVC(C=450, kernel='linear'), Accuracy=0.9208333333333333, CV_Accuracy=0.9
# CV_Scores=[0.921875   0.92708333 0.85416667 0.859375   0.9375    ]

# %% [markdown]
# #### Refreshed Simulation

# %%
S_scores = []

for model in models:
    fitted_model,score,cv_score = mlf.std_split_fit_and_scores(
        mlf.apply_preprosessing(initial_list[2]),model)
    print(f"Model={model}, Accuracy={score}, CV_Accuracy={cv_score.mean()}")
    print(f"CV_Scores={cv_score}")
    S_scores.append(cv_score.mean())

plt.plot(model_names, S_scores)
plt.xlabel('SVM Model')
plt.ylabel('Cross-Validated Accuracy')
plt.show()
# Out:
# Model=SVC(degree=5, kernel='poly'), Accuracy=0.5625, CV_Accuracy=0.5479166666666667
# CV_Scores=[0.55729167 0.609375   0.55208333 0.44270833 0.578125  ]
# Model=SVC(C=450), Accuracy=1.0, CV_Accuracy=0.99375
# CV_Scores=[0.98958333 1.         0.98958333 0.98958333 1.        ]
# Model=SVC(C=450, coef0=0.5, kernel='poly'), Accuracy=0.9958333333333333, CV_Accuracy=0.9947916666666667
# CV_Scores=[0.98958333 1.         0.99479167 0.98958333 1.        ]
# Model=SVC(C=450, degree=5, kernel='poly'), Accuracy=1.0, CV_Accuracy=0.9947916666666667
# CV_Scores=[0.98958333 1.         0.984375   1.         1.        ]
# Model=SVC(C=450, kernel='linear'), Accuracy=0.9208333333333333, CV_Accuracy=0.9
# CV_Scores=[0.921875   0.92708333 0.85416667 0.859375   0.9375    ]

# %% [markdown]
# ## 8 Qubits

# %%
nr_qubits2 =8

initial_list2 = ttf.get_HSR_array_all_backends(
    nr_qubits2,dir_='../../../',updated_results=True) #[df_h,df_s, df_r]
# test_table_HSR8q = mlf.get_HSR_test_table(initial_list2)

# %% [markdown]
# ### Hardware

# %%
df_H8 = initial_list2[0]
df_H8p = mlf.apply_preprosessing(df_H8)
S_scores = []

for model in models:
    fitted_model,score,cv_score = mlf.std_split_fit_and_scores(df_H8p,model)
    print(f"Model={model}, Accuracy={score}, CV_Accuracy={cv_score.mean()}")
    print(f"CV_Scores={cv_score}")
    S_scores.append(cv_score.mean())

plt.plot(model_names, S_scores)
plt.xlabel('SVM Model')
plt.ylabel('Cross-Validated Accuracy')
plt.show()
# Out:
# Model=SVC(degree=5, kernel='poly'), Accuracy=0.23333333333333334, CV_Accuracy=0.32291666666666663
# CV_Scores=[0.25       0.25       0.3125     0.375      0.42708333]
# Model=SVC(C=450), Accuracy=1.0, CV_Accuracy=1.0
# CV_Scores=[1. 1. 1. 1. 1.]
# Model=SVC(C=450, coef0=0.5, kernel='poly'), Accuracy=1.0, CV_Accuracy=1.0
# CV_Scores=[1. 1. 1. 1. 1.]
# Model=SVC(C=450, degree=5, kernel='poly'), Accuracy=1.0, CV_Accuracy=1.0
# CV_Scores=[1. 1. 1. 1. 1.]
# Model=SVC(C=450, kernel='linear'), Accuracy=1.0, CV_Accuracy=1.0
# CV_Scores=[1. 1. 1. 1. 1.]

# %% [markdown]
# ### Old Simulation

# %%
df_S8 = initial_list2[1]
df_S8p = mlf.apply_preprosessing(df_S8)
S_scores = []

for model in models:
    fitted_model,score,cv_score = mlf.std_split_fit_and_scores(df_S8p,model)
    print(f"Model={model}, Accuracy={score}, CV_Accuracy={cv_score.mean()}")
    print(f"CV_Scores={cv_score}")
    S_scores.append(cv_score.mean())

plt.plot(model_names, S_scores)
plt.xlabel('SVM Model')
plt.ylabel('Cross-Validated Accuracy')
plt.show()
# Out:
# Model=SVC(degree=5, kernel='poly'), Accuracy=0.825, CV_Accuracy=0.7072916666666667
# CV_Scores=[0.69791667 0.66145833 0.734375   0.77604167 0.66666667]
# Model=SVC(C=450), Accuracy=0.975, CV_Accuracy=0.9854166666666666
# CV_Scores=[0.97916667 0.97916667 0.984375   1.         0.984375  ]
# Model=SVC(C=450, coef0=0.5, kernel='poly'), Accuracy=0.9833333333333333, CV_Accuracy=0.9947916666666667
# CV_Scores=[0.99479167 0.98958333 0.98958333 1.         1.        ]
# Model=SVC(C=450, degree=5, kernel='poly'), Accuracy=0.9833333333333333, CV_Accuracy=0.99375
# CV_Scores=[0.98958333 0.98958333 0.98958333 1.         1.        ]
# Model=SVC(C=450, kernel='linear'), Accuracy=0.9916666666666667, CV_Accuracy=0.9927083333333334
# CV_Scores=[0.98958333 0.984375   0.98958333 1.         1.        ]

# %% [markdown]
# ### Refreshed Simulation

# %%
df_S8 = initial_list2[2]
df_S8p = mlf.apply_preprosessing(df_S8)
S_scores = []

for model in models:
    fitted_model,score,cv_score = mlf.std_split_fit_and_scores(df_S8p,model)
    print(f"Model={model}, Accuracy={score}, CV_Accuracy={cv_score.mean()}")
    print(f"CV_Scores={cv_score}")
    S_scores.append(cv_score.mean())

plt.plot(model_names, S_scores)
plt.xlabel('SVM Model')
plt.ylabel('Cross-Validated Accuracy')
plt.show()
# Out:
# Model=SVC(degree=5, kernel='poly'), Accuracy=0.5875, CV_Accuracy=0.575
# CV_Scores=[0.58854167 0.49479167 0.66666667 0.59895833 0.52604167]
# Model=SVC(C=450), Accuracy=0.9875, CV_Accuracy=0.9895833333333333
# CV_Scores=[0.97916667 1.         0.984375   0.99479167 0.98958333]
# Model=SVC(C=450, coef0=0.5, kernel='poly'), Accuracy=0.9916666666666667, CV_Accuracy=0.99375
# CV_Scores=[0.984375   1.         0.99479167 1.         0.98958333]
# Model=SVC(C=450, degree=5, kernel='poly'), Accuracy=0.9916666666666667, CV_Accuracy=0.9958333333333333
# CV_Scores=[0.984375   1.         1.         1.         0.99479167]
# Model=SVC(C=450, kernel='linear'), Accuracy=0.9916666666666667, CV_Accuracy=0.9927083333333334
# CV_Scores=[0.984375   1.         0.98958333 1.         0.98958333]

# %% [markdown]
# ## 16 Qubits

# %% [markdown]
# ### Old Simulation

# %%
nr_qubits3 =16
df_S16 = dpf.get_expanded_df('Simulation',nr_qubits3, True)
df_S16p = mlf.apply_preprosessing(df_S16)

# %%
S_scores = []

for model in models:
    fitted_model,score,cv_score = mlf.std_split_fit_and_scores(df_S16p,model)
    print(f"Model={model}, Accuracy={score}, CV_Accuracy={cv_score.mean()}")
    print(f"CV_Scores={cv_score}")
    S_scores.append(cv_score.mean())

plt.plot(model_names, S_scores)
plt.xlabel('SVM Model')
plt.ylabel('Cross-Validated Accuracy')
plt.show()
# Out:
# Model=SVC(degree=5, kernel='poly'), Accuracy=0.9361702127659575, CV_Accuracy=0.9169018090795312
# CV_Scores=[0.84574468 0.93617021 0.91489362 0.88770053 1.        ]
# Model=SVC(C=450), Accuracy=1.0, CV_Accuracy=1.0
# CV_Scores=[1. 1. 1. 1. 1.]
# Model=SVC(C=450, coef0=0.5, kernel='poly'), Accuracy=1.0, CV_Accuracy=0.9989361702127659
# CV_Scores=[1.         0.99468085 1.         1.         1.        ]
# Model=SVC(C=450, degree=5, kernel='poly'), Accuracy=1.0, CV_Accuracy=0.9957333029923768
# CV_Scores=[1.         0.9893617  1.         1.         0.98930481]
# Model=SVC(C=450, kernel='linear'), Accuracy=1.0, CV_Accuracy=0.9989361702127659
# CV_Scores=[1.         0.99468085 1.         1.         1.        ]

# %% [markdown]
# ### Refreshed Simulation

# %%
df_R16 = dpf.get_expanded_df('Refreshed_Simulation',nr_qubits3, True)
df_R16p = mlf.apply_preprosessing(df_R16)

# %%
S_scores = []

for model in models:
    fitted_model,score,cv_score = mlf.std_split_fit_and_scores(df_R16p,model)
    print(f"Model={model}, Accuracy={score}, CV_Accuracy={cv_score.mean()}")
    print(f"CV_Scores={cv_score}")
    S_scores.append(cv_score.mean())

plt.plot(model_names, S_scores)
plt.xlabel('SVM Model')
plt.ylabel('Cross-Validated Accuracy')
plt.show()
# Out:
# Model=SVC(degree=5, kernel='poly'), Accuracy=0.802547770700637, CV_Accuracy=0.8530539682539683
# CV_Scores=[0.84126984 0.824      0.92       0.888      0.792     ]
# Model=SVC(C=450), Accuracy=1.0, CV_Accuracy=1.0
# CV_Scores=[1. 1. 1. 1. 1.]
# Model=SVC(C=450, coef0=0.5, kernel='poly'), Accuracy=1.0, CV_Accuracy=1.0
# CV_Scores=[1. 1. 1. 1. 1.]
# Model=SVC(C=450, degree=5, kernel='poly'), Accuracy=1.0, CV_Accuracy=1.0
# CV_Scores=[1. 1. 1. 1. 1.]
# Model=SVC(C=450, kernel='linear'), Accuracy=1.0, CV_Accuracy=1.0
# CV_Scores=[1. 1. 1. 1. 1.]
