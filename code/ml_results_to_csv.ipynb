# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
from sklearn import model_selection,svm
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

import data_process_funcs
import meta_dataframe_functions
import ml_funcs

# %% [markdown]
# {nr_qubits, t_v exp_type, t_v circuits, test exp_type, test circuit}, {ml alg, ml settings},{acurracy, cross val accuracy}

# %%
knn = KNeighborsClassifier(n_neighbors=3)
print(knn.get_params() )
# Out:
# {'algorithm': 'auto', 'leaf_size': 30, 'metric': 'minkowski', 'metric_params': None, 'n_jobs': None, 'n_neighbors': 3, 'p': 2, 'weights': 'uniform'}

# %%
model1 = SVC(kernel='linear')
print(model1.get_params())


#C, coef0, decision_function_shape,degree,gamma,kernel,tol
# Out:
# {'C': 1.0, 'break_ties': False, 'cache_size': 200, 'class_weight': None, 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'linear', 'max_iter': -1, 'probability': False, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}

# %%
df = meta_dataframe_functions.blank_meta_df()
meta_dataframe_functions.load_meta_df(df,'Generic_Simulation')
df.head(20)
# Out:
#   nr_qubits    backend   sim circuit_type  \
# 0         4  genericV2  True            1
# 1         4  genericV2  True            2
# 2         4  genericV2  True            3
# 3         8  genericV2  True            1
# 4         8  genericV2  True            2
# 5         8  genericV2  True            3
# 6        16  genericV2  True            1
# 7        16  genericV2  True            2
# 8        16  genericV2  True            3
#
#                                           file_path
# 0    ../Simulated_results/4q/4q_fake_genericV21.csv
# 1    ../Simulated_results/4q/4q_fake_genericV22.csv
# 2    ../Simulated_results/4q/4q_fake_genericV23.csv
# 3    ../Simulated_results/8q/8q_fake_genericV21.csv
# 4    ../Simulated_results/8q/8q_fake_genericV22.csv
# 5    ../Simulated_results/8q/8q_fake_genericV23.csv
# 6  ../Simulated_results/16q/16q_fake_genericV21.csv
# 7  ../Simulated_results/16q/16q_fake_genericV22.csv
# 8  ../Simulated_results/16q/16q_fake_genericV23.csv

# %%
df.tail(200)
# Out:
#    nr_qubits    backend   sim circuit_type  \
# 0          4  genericV2  True            1
# 1          4  genericV2  True            2
# 2          4  genericV2  True            3
# 3          4  genericV2  True            1
# 4          4  genericV2  True            2
# 5          4  genericV2  True            3
# 6          4  genericV2  True            1
# 7          4  genericV2  True            2
# 8          4  genericV2  True            3
# 9          8  genericV2  True            1
# 10         8  genericV2  True            2
# 11         8  genericV2  True            3
# 12         8  genericV2  True            1
# 13         8  genericV2  True            2
# 14         8  genericV2  True            3
# 15         8  genericV2  True            1
# 16         8  genericV2  True            2
# 17         8  genericV2  True            3
# 18        16  genericV2  True            1
# 19        16  genericV2  True            2
# 20        16  genericV2  True            3
# ...

# %%
dfH = meta_dataframe_functions.blank_meta_df()
meta_dataframe_functions.load_meta_df(dfH,'Hardware')
dfH.head(20)
# Out:
#    nr_qubits   backend    sim circuit_type  \
# 0          4    torino  False            1
# 1          4    torino  False            2
# 2          4    torino  False            3
# 3          4  brisbane  False            1
# 4          4  brisbane  False            2
# 5          4  brisbane  False            3
# 6          8    torino  False            1
# 7          8    torino  False            2
# 8          8    torino  False            3
# 9          8  brisbane  False            1
# 10         8  brisbane  False            2
# 11         8  brisbane  False            3
#
#                                       file_path
# 0     ../Hardware_results/4q/4q_ibm_torino1.csv
# 1     ../Hardware_results/4q/4q_ibm_torino2.csv
# 2     ../Hardware_results/4q/4q_ibm_torino3.csv
# 3   ../Hardware_results/4q/4q_ibm_brisbane1.csv
# 4   ../Hardware_results/4q/4q_ibm_brisbane2.csv
# 5   ../Hardware_results/4q/4q_ibm_brisbane3.csv
# 6     ../Hardware_results/8q/8q_ibm_torino1.csv
# ...
