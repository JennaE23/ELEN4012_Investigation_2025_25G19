# %% [markdown]
# # Investigation: Hardware Identification via noise fingerprint exploration
# The code to produce the circuits then the code to run the circuits on hardware is given below. Another file has the code to run the ideal circuits, and the code to extract and store the normalised noise profiles.

# %% [markdown]
# ## Imports

# %%
from qiskit_ibm_runtime import QiskitRuntimeService
from investigation_functions import data_extract_funcs
import config

# %% [markdown]
# ## Backends
# The two backends that are accessible on the free plan are torino and brisbane.
# ibm_torino is Heron r1, ibm_brisbane is Eagle ...
#
#
# Otherwise it would be nice to use ibm_kingston (Heron r2) and ibm_pittsburgh (Heron r3) which are not so busy.
#
# Note: It would be interesting to see 2 different hardware with same chip.
#
# All of the available IBM QPUs can be found at this link:
# https://quantum.cloud.ibm.com/computers

# %% [markdown]
# The circuits that will be tested in this investigation will have circuit sizes of 4, 8, 16, and 32 qubits

# %% [markdown]
# # Sending Set to IBM backend

# %% [markdown]
# Loop for backend runs

# %%
service = QiskitRuntimeService(channel = config.channel, token = config.tokenJAPI, instance = config.instanceJAPI)

# %%
service.backends()
# Out:
# [<IBMBackend('ibm_brisbane')>,
#  <IBMBackend('ibm_fez')>,
#  <IBMBackend('ibm_pittsburgh')>,
#  <IBMBackend('ibm_marrakesh')>,
#  <IBMBackend('ibm_torino')>,
#  <IBMBackend('ibm_kingston')>]

# %%
backends = ['ibm_fez','ibm_marrakesh']

# %%
##simple for loop to make data collection automated
# nr_of_runs = 50
# nr_qubits =8
# file_name = "Job_IDs_8qubits_fez_marr.txt"


# for run in range(nr_of_runs): 
#     lines =circuit_funcs.send_and_record(nr_qubits,file_name,backends,service)

# %% [markdown]
# # How to read the results
# Format of text file is :
# - ibm torino job ID
# - ibm brisbane job ID
# - date and time of jobs

# %% [markdown]
# ## Extracting Data

# %%
# This is the set up to use results_to_csv2
nr_qubits = 8
dir = "../Hardware_results/testing/"
job_id_file = dir+"Job_IDs_Actual8_qubits_last_41.txt"
create_csvs_=False

file_names_ = data_extract_funcs.make_file_names(backends[0],nr_qubits)+data_extract_funcs.make_file_names(backends[1],nr_qubits)
print(file_names_)
# Out:
# ['8q_ibm_fez1.csv', '8q_ibm_fez2.csv', '8q_ibm_fez3.csv', '8q_ibm_marrakesh1.csv', '8q_ibm_marrakesh2.csv', '8q_ibm_marrakesh3.csv']

# %%
#
data_extract_funcs.results_to_csv2(nr_qubits,dir,file_names_,job_id_file, create_csvs_,service)

# %%
# pls test using this block:
nr_qubits = 4
dir = "../Hardware_results/testing/"
job_id_file = dir+"testing_ids.txt"
create_csvs_= False
# file_names_ = file_names_test

data_extract_funcs.results_to_csv2(nr_qubits,dir,file_names_,job_id_file, create_csvs_)
